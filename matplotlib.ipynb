# %% [markdown]
# <a href="https://colab.research.google.com/github/ravidhwn01/AML/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# So, It's very important that on which type of data you are working
#
# it will help us to think , what type of graph we should plot
#
# important library
# -  numpy
# - pandas
# - matplotlib.pyplot
# - seaborn

# %%
#import the library
# type of data
# 1. Numerical data
# 2. Categorical data

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# create dataset for price and years  with values
year =[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
price  = [25000, 28000, 32000, 5000, 12000, 23000, 45000, 48000, 52000, 25000, 60000]
plt.plot(year, price)

# %%
batsman = pd.read_csv('sharma-kohli.csv')
batsman.head()
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364

# %%
plt.plot( batsman['index'],batsman['RG Sharma'])
plt.plot( batsman['index'],batsman['V Kohli'])
# provide labels to graph
plt.xlabel('Seasons')
plt.ylabel('Runs')
plt.title('RG Sharma vs V Kohli')
# plt.plot( batsman['RG Sharma'],batsman['index'])
# plt.plot( batsman['V Kohli'],batsman['index'])
# Out:
# Text(0.5, 1.0, 'RG Sharma vs V Kohli')

# %% [markdown]
# Above we have studies some properties  like : color, linestyle, linewidth,
# legend() , plot.show() ect.

# %% [markdown]
# Scatter plot : work on Bivariate Dataset
#  -  Numerical vs Numerical
#  - use case - finding correlation

# %%
x = np.linspace(-10,10,50)
y = 10*x + 1 + np.random.randint(0,300,50)
print(y)
plt.scatter(x,y)
# Out:
# [ 63.          69.08163265 144.16326531 100.24489796 -70.67346939
#  138.40816327  -7.51020408  -8.42857143 -61.34693878  57.73469388
#  -19.18367347  50.89795918 196.97959184  88.06122449 140.14285714
#   15.2244898  224.30612245 247.3877551  134.46938776 257.55102041
#   -1.36734694  -8.28571429  39.79591837  98.87755102 207.95918367
#  134.04081633  51.12244898 196.20408163 277.28571429 119.36734694
#   84.44897959 174.53061224 123.6122449  273.69387755  86.7755102
#   75.85714286 239.93877551  70.02040816 292.10204082 359.18367347
#  127.26530612 266.34693878 187.42857143 243.51020408 294.59183673
#  189.67346939 270.75510204 185.83673469 367.91836735 400.        ]

# %%
#plt.scatter on pandas data
df  = pd.read_csv('batter.csv')
ndf = df.head(50)

# %%
plt.scatter(ndf['avg'],ndf['strike_rate'])
