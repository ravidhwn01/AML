# %%
import pandas as pd

# %%
park=pd.read_excel("/content/drive/MyDrive/Dataset/new_park.xlsx")

# %%
park.head()
# Out:
#     1.000000e+00   8.811235e-02   4.169741e-02   4.803597e-04  -3.723304e-06  \
# 0              1       0.031089       0.027108       0.000314  -2.214722e-07
# 1              1       0.032581       0.024174       0.000280  -4.151454e-06
# 2              1       0.055767       0.025802       0.000285  -7.516230e-06
# 3              1       0.109154       0.058189       0.000686  -2.315075e-06
# 4              1       0.037592       0.025793       0.000306   7.725535e-07
#
#     4.216638e-04   2.458381e+00   6.332164e-07   4.702108e+01   1.366430e+03  \
# 0       0.000216       0.754288   1.868647e-07      13.982754     417.217249
# 1       0.000236       0.906992   1.970592e-07      17.916749     539.927763
# 2       0.000401       1.155191   8.018045e-07      47.307997    1392.038999
# 3       0.000375       2.914247   6.511559e-07      37.297173    1075.580332
# 4       0.000108       0.968243   1.300052e-07      21.916628     664.710687
#
#    ...   2.527583e+00   7.088978e+00   1.975326e+01   5.433505e+01  \
# 0  ...       1.999637       5.610448      15.626164      42.943275
# 1  ...       2.135337       5.987349      16.656580      45.664487
# 2  ...       2.565053       7.190456      20.027376      54.984010
# 3  ...       2.421649       6.794426      18.930947      52.036600
# 4  ...       2.199489       6.172819      17.194790      47.249466
#
#     1.455286e+02   3.750974e+02   9.212966e+02   2.137080e+03   4.697131e+03  \
# 0     115.014975     296.320795     728.284936    1689.586636    3713.818933
# 1     122.416506     315.209203     775.269129    1799.191348    3954.806860
# 2     147.380361     379.623517     933.131317    2164.248742    4757.142198
# 3     139.404056     359.231383     881.985195    2045.855194    4502.106643
# 4     126.589594     326.072560     801.486390    1859.154995    4088.830256
#
#     9.931208e+03
# 0    7851.139360
# 1    8351.598804
# 2   10054.337528
# 3    9507.815319
# 4    8638.195110
#
# [5 rows x 310 columns]

# %%
park[1].nunique()
# Out:
# 2

# %%
park.isnull().sum()
# Out:
#  1.000000       0
#  0.088112       0
#  0.041697       0
#  0.000480       0
# -0.000004       0
#                ..
#  375.097397     0
#  921.296579     0
#  2137.079844    0
#  4697.131077    0
#  9931.208257    0
# Length: 310, dtype: int64

# %%
park.shape
# Out:
# (125, 310)

# %%
x=park.drop(columns=[1],axis=1)
y=park[1]
x.shape
# Out:
# (125, 309)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((100, 309), (25, 309), (100,), (25,))

# %%
# Convert all column names to strings
x_train.columns = x_train.columns.astype(str)
x_test.columns = x_test.columns.astype(str)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log=LogisticRegression()
log.fit(x_train,y_train)
y_pred=log.predict(x_test)

# %%
import numpy as np
error=np.mean(y_pred-y_test)
error
# Out:
# 0.28

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_test,y_pred)
# Out:
# 0.48

# %%
com=confusion_matrix(y_test,y_pred)
com
# Out:
# array([[ 0, 10],
#        [ 3, 12]])
