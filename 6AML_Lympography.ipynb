# %%
import pandas as pd

# %%
lympo=pd.read_csv('/content/drive/MyDrive/Dataset/lymphography.data',delimiter=',')

# %%
lympo.head(10)
# Out:
#    3  4  2  1  1.1  1.2  1.3  1.4  2.1  1.5  2.2  2.3  2.4  4.1  8  1.6  1.7  \
# 0  2  3  2  1    1    2    2    1    2    1    3    3    2    3  4    2    2
# 1  3  3  2  2    2    2    2    2    2    1    4    3    3    4  8    3    2
# 2  3  3  1  1    1    1    2    1    2    1    3    3    4    4  4    3    1
# 3  2  3  1  1    1    1    1    1    1    1    2    2    4    3  5    1    2
# 4  2  2  1  1    1    1    1    1    2    1    3    3    3    3  6    3    1
# 5  2  2  2  1    1    1    1    1    2    1    2    3    2    3  8    2    1
# 6  2  3  2  1    1    1    2    1    2    1    2    2    2    2  1    3    1
# 7  3  2  2  1    1    1    1    1    2    1    3    2    2    2  8    3    1
# 8  3  2  1  1    1    1    1    1    2    1    2    2    3    3  5    3    1
# 9  2  2  2  2    1    2    2    1    2    1    3    2    4    3  5    1    2
#
#    2.5  2.6
# 0    2    2
# 1    2    7
# 2    2    6
# 3    2    1
# 4    2    4
# 5    1    1
# 6    1    1
# 7    2    5
# 8    1    2
# 9    2    3

# %%
lympo.shape
# Out:
# (147, 19)

# %%
lympo.columns
# Out:
# Index(['3', '4', '2', '1', '1.1', '1.2', '1.3', '1.4', '2.1', '1.5', '2.2',
#        '2.3', '2.4', '4.1', '8', '1.6', '1.7', '2.5', '2.6'],
#       dtype='object')

# %%
lympo.nunique()
# Out:
# 3      4
# 4      4
# 2      2
# 1      2
# 1.1    2
# 1.2    2
# 1.3    2
# 1.4    2
# 2.1    2
# 1.5    3
# 2.2    4
# 2.3    3
# 2.4    4
# 4.1    4
# 8      8
# 1.6    3
# 1.7    2
# 2.5    2
# 2.6    8
# dtype: int64

# %%
lympo.isnull().sum()
# Out:
# 3      0
# 4      0
# 2      0
# 1      0
# 1.1    0
# 1.2    0
# 1.3    0
# 1.4    0
# 2.1    0
# 1.5    0
# 2.2    0
# 2.3    0
# 2.4    0
# 4.1    0
# 8      0
# 1.6    0
# 1.7    0
# 2.5    0
# 2.6    0
# dtype: int64

# %%
x=lympo.drop(['1'],axis=1)
y=lympo['1']

# %%
x.shape,y.shape
# Out:
# ((147, 18), (147,))

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((117, 18), (30, 18), (117,), (30,))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error,confusion_matrix,accuracy_score

# %%
log=LogisticRegression()
log.fit(x_train,y_train)
y_pred=log.predict(x_test)
error=mean_squared_error(y_test,y_pred)
print(error)
# Out:
# 0.2

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[22,  1],
#        [ 5,  2]])

# %%
cvp=cross_val_score(log,x_train,y_train,cv=5)
cvp
# Out:
# array([0.91666667, 0.91666667, 0.86956522, 0.82608696, 0.91304348])
